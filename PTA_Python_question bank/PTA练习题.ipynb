# %% [markdown]
# # 编程题

# %%
# 1
a = int(input())
b = int(input())
print(a+b)

# %%
# 2
a, b, c = input().split(' ')
a = int(a)
b = int(b)
c = int(c)
print(b*b-4*a*c)
# Out:
# -44

# %%
# 3
print('人生苦短，我学Python')

# %%
# 4
m = int(input())
sum1 = 0
for i in range(11, m+1):
    sum1 += i       # 求11到m的和
print('sum = %d' %sum1)
# Out:
# sum = 4040

# %%
# 5
x = float(input())
if x==0:
    result = 0
else:
    result = 1/x
# 字符串的精度控制
print('f(%.1f) = %.1f' %(x, result))
# Out:
# f(0.0) = 0.0

# %%
# 6
power = float(input())
if power<0:
    print('Invalid Value!')
elif power<=50:
    cost = 0.53*power
    print('cost = %.2f' %cost)
else:
    cost = 50*0.53+(power-50)*(0.53+0.05)
    print('cost = %.2f' %cost)
# Out:
# cost = 55.50

# %% [markdown]
# # 7——————————————————

# %%
# 7
a, n = input().split(' ')
a = int(a)
n = int(n)
n1 = n
num = 0     # 定义num记录最大的数——aaaa(n个a)
# 通过累加，从最大位数开始构建a00...+a00+a0+a的形式
while n >0:
    num += a*(10**(n-1))    
    n -= 1
sum1 = 0    # 定义累加和变量
# 从最大数num = aaa...(n个a)开始累加
# 每次对num//10，即去掉个位数字
for i in range(n1):
    sum1 += num
    num = num//10
print(f's = {sum1}')
# Out:
# s = 246

# %%
# 8 
N = int(input())
count = N
sum1 = 0    # 定义求和变量
# eg:求前三项和：1/5 + 1/3 + 1/1
for i in range(count):  # 循环N次
    num = 1/(2*N-1)    # 写出通项公式
    sum1 += num   # 累加n次通项公式
    N -= 1              # 累加一次，通项参数-1
print('sum = %.6f' %sum1)
# Out:
# sum = 2.549541

# %%
# 9
N = int(input())
count = N
sum1 = 0    # 求和变量
for i in range(count):
    num = N/(2*N-1)     # 通项公式
    if N%2 == 0:    # 偶数项
        num = -num
    else:           # 奇数项
        num = num
    sum1 += num
    N -= 1
print('%.3f' %sum1)
# Out:
# 0.917

# %%
# 10
A, B = input().split(',')
A = A.strip()   # 消除字符串A前后的空白字符
B = int(B)  # 将B转为整数，从而进行遍历
C = ''      # 定义空字符串用于字符串拼接
for i in range(B):      # 循环B次
    C += A              # 每次循环，空字符串+‘A'
C = int(C)              # 将结果转为整数
print(C)
# Out:
# 3333

# %%
# 11
a, b = input().split(',')
a = int(a)
b = int(b)
result = 0  # 用于存储结果
n = 0   # 定义n，来记录进制的乘方数字
while a//10 != 0:   # 保证a至少有2位
    result += (a%10)*(b**n)  # 取a的最右侧数字进行计算
    a = a//10   # 计算一次，a就去掉最右侧数字
    n += 1  # 从个位开始，每次向左侧计算时，n+1
result += a*(b**n)  # 原始a最左侧的数字计算
print(result)
# Out:
# 37

# %%
# 12
a,b,c = input().split(' ')
a = int(a)
b = int(b)
c = int(c)
# 将数据存入列表
list1 = [a, b, c]
list1.sort()    # 将列表中元素进行排序（正序）
print(f'{list1[0]}->{list1[1]}->{list1[2]}')
# Out:
# 2->4->8

# %%
# 13
lower, upper = input().split(' ')
lower = int(lower)
upper = int(upper)
if lower <= upper:
    print("fahr celsius")
    # 此处遍历时，upper必须要+1，
    for F in range(lower, upper+1, 2):
        C = 5*(F-32)/9
        print('%d%6.1f' %(F, C))
else:
    print("Invalid.")
# Out:
# fahr celsius
# 32   0.0
# 34   1.1

# %%
# 14
m, n = input().split(' ')
m = int(m)
n = int(n)
result = 0  # 用于累加结果
for i in range(m,n+1):
    an = (i**2)+1/i   # 通项公式
    result += an
print('sum = %.6f' %result)
# Out:
# 355.845635

# %%
# 15
import math
a, b, c = input().split(' ')
a = int(a)
b = int(b)
c = int(c)
# math.sqrt(x)——x开根号
if a+b>c and a+c>b and b+c>a:
    s = (a+b+c)/2       # 周长
    area = math.sqrt(s*(s-a)*(s-b)*(s-c))  #面积
    print('area = %.2f; perimeter = %.2f' %(area, float(a+b+c)))
else:
    print('These sides do not correspond to a valid triangle')
# Out:
# area = 7.15; perimeter = 13.00

# %%
# 16
x = int(input())
if x <= 15:
    y = (4*x)/3
else:
    y = 2.5*x-17.5
print('%.2f' %y)
# Out:
# 22.50

# %%
# 17
A, B = input().split(' ')
A = int(A)
B = int(B)
result = 0  # 定义变量，用于求和
count = 1   # 定义count，用于计数
for i in range(A, B+1):
    result += i
    print('%5d'%i,end ='')
    # 每5次则换行
    if count%5 == 0:    
        print()
    count += 1  # 每次循环count+1
# count此时等于数字个数，若数字个数非5的倍数，则换行
# 若为5的倍数，则在上述循环中以及实现换行了
count = count -1
if count%5 != 0:
    print()
print(f'Sum = {result}')
# Out:
#    -3   -2   -1    0    1
#     2    3    4    5    6
#     7    8
# Sum = 30

# %% [markdown]
# # 18--------------------无限输入+列表推导式用法

# %%
# 18
"""
无限输入：以空格分割输入值的无限输入
——通过字符串接收输入值，再用字符串的分割将输入值拆分
——str1 = input()
——list1 = str1.split(' ')
"""
# 用字符串形式接收输入
height_srt = input()
# 根据空格，分割字符串，返回列表
height_list= height_srt.split(' ')
# 列表推导式——转换列表中元素数据类型
height_list = [int(i) for i in height_list]
sum1 = 0    # 用于记录数据和
for height in height_list:
    sum1 += height  # 所有身高数据和
# 身高平均值
height_avg = sum1/len(height_list)
"""
列表推导式
for i in height_list:
    if i > height_avg:
        i
"""
height_list = [i for i in height_list if i > height_avg]
for height in height_list:
    print(height,end=' ')
# Out:
# 143 174 164

# %% [markdown]
# # 补充知识：try-except 异常捕获
# """
# try:
#     # 可能出现异常的核心代码
#     待执行代码块
# except 异常类型:
#     # 有异常时执行的处理逻辑
#     异常处理代码块
# else:
#     # 「无异常时」才执行的逻辑（可选）
#     无异常处理代码块
# finally:
#     # 「无论是否有异常」都会执行的逻辑（可选，用于资源释放等）
#     最终执行代码块
# """

# %%
# 19
N = int(input())
# 构建Z-M对应表——字典
dict_ZM = {
    '0': '1',
    '1': '0',
    '2': 'X',
    '3': '9',
    '4': '8',
    '5': '7',
    '6': '6',
    '7': '5',
    '8': '4',
    '9': '3',
    '10': '2'
}
# 创建变量，记录是否全通过，若其中有一个ID有误，则赋值其为False
all_pass = True
# 建立空列表，存储所有ID
ID_list = []
# 遍历N次，将N个ID存入ID——list列表
for i in range(N):
    ID = input()
    ID_list.append(ID)
# 从ID列表中逐一取出ID
for ID_single in ID_list:
    # ID前17位提取——字符串
    ID_pre17 = ID_single[0:17]
    # try-except 异常捕获
    # 检查ID前17位是否均为数字
    try:
         ID_pre17 = int(ID_single[0:17])
    except:
         print(ID_single)
         all_pass = False
     # 若ID前17位均为数字
    else:
        # 提取ID前17位——字符串
        ID_pre17 = ID_single[0:17]
        # 遍历ID前17位——字符串，并将其存入列表中
        list_ID_pre17 = []
        for num in ID_pre17:
            # 字符串转整型
            num = int(num)
            list_ID_pre17.append(num)
        # 加权求和
        s1 = list_ID_pre17[0] * 7 + list_ID_pre17[1] * 9 + list_ID_pre17[2] * 10 + list_ID_pre17[3] * 5 + list_ID_pre17[
            4] * 8 + list_ID_pre17[5] * 4 + list_ID_pre17[6] * 2 + list_ID_pre17[7] * 1 + list_ID_pre17[8] * 6 + \
            list_ID_pre17[9] * 3 + list_ID_pre17[10] * 7 + list_ID_pre17[11] * 9 + list_ID_pre17[12] * 10 + \
            list_ID_pre17[13] * 5 + list_ID_pre17[14] * 8 + list_ID_pre17[15] * 4 + list_ID_pre17[16] * 2
        Z = s1 % 11
        # 将Z值转为字符串，进行判断
        Z = str(Z)
        # 若ID第18位数字 != M对应值
        if ID_single[17] != dict_ZM[Z]:
            print(ID_single)
            all_pass = False
if all_pass:
    print('All passed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 2
#       1 # 19
# ----> 2 N = int(input())
#       3 # 构建Z-M对应表——字典
#       4 dict_ZM = {
#       5     '0':'1',
#       6     '1':'0',
#    (...)
#      15     '10':'2'
#      16 }
#
# ValueError: invalid literal for int() with base 10: '4 320124198808240056 12010X198901011234 110108196711301866 37070419881216001X'

# %%
# 20
str1 = input()
str2, str3 = input().split(' ')
list1 = []      # 新建空列表，用来存储结果
count = 0       # 创建变量，用于记录索引
# 遍历字符串，若某个元素相符，则传入索引与该元素
for i in str1:
    if i == str2:
        list1.append(str(count)+' '+str2)
    if i == str3:
        list1.append(str(count)+' '+str3)
    count += 1
# 列表反转
list1_rev = list1[::-1]
for element in list1_rev:
    print(element)
# Out:
# 11 p
# 10 p
# 8 s
# 7 s
# 5 s
# 4 p
# 3 s
# 0 p

# %%
# 21
str1 = input()
str2 = input()
if str1 in str2:
    # 字符串反向
    str3 = str2[::-1]
    # 取str3（反向字符串）中str1的最小索引值
    index1 = str3.index(str1)
    result_index = len(str2)-index1-1   # 正序的最大下标结果 
    print(f'index = {result_index}')
else:
    print(f'Not Found')
# Out:
# Not Found

# %%
# 22
str1 = input()
list_str1 = list(str1)
# 建立空列表来保存结果
list_result = []
# 通过临时变量i接收列表元素，判断是否为‘数字’
for i in list_str1:
    # 尝试临时变量是否可以转为整数
    try:
        i = int(i)
    # 若不能转整数，则仍保持字符串格式
    except:
        i = str(i)
    # 若可以转为整数，则将i写入list_result
    else:
        list_result.append(i)
# 定义空字符串来接收结果
result = ''
# 遍历结果列表
for num in list_result:
    num = str(num)  # 将结果数字单个取出，并转为字符串进行拼接
    result += num
# 将结果转为整数输出
print(int(result))
# Out:
# 825

# %%
# 23
"""
无限输入——以空格分割来输出数据
——input().split(' ')
——返回列表（字符串元素）
"""
# 将以空格分割的输入值转为列表（字符串元素）
list_num = input().split(' ')
# 取出列表中第一个元素——输入数据的个数
N = list_num.pop(0)
# 对数据列表进行去重——将数据列表转为集合
set_num = set(list_num)
# 将集合进行正序排序——转为列表
set_list = sorted(set_num)
list1 = []
# 遍历去重后的数字，统计其在原始列表中的个数，并将结果存入list1
for i in set_list:
    count_i = list_num.count(i)
    list1.append(count_i)
# 找到list1中最大的数字——出现次数最大值
count_max = int(max(list1))
# 找出出现次数最大值对应的数字
index_count_max = list1.index(count_max)
num_result = int(set_list[index_count_max])

print('%d %d' %(num_result, count_max))
# Out:
# 3 4

# %%
# 24
N = int(input())
list_num = input().split(' ')
index0 = 0
for i in list_num:
    i = int(i)
    list_num[index0] = i
    index0 += 1
max_num = max(list_num)
max_index = list_num.index(max_num)
print('%d %d' %(int(max_num), int(max_index)))
# Out:
# 10 2

# %%
# 25
str1 = input()
str1_rev = str1[::-1]
print(str1_rev)
# Out:
# !dlroW olleH

# %% [markdown]
# # str.join()——join()方法
# # 通用模板
# 保留的字符集合 = {"字符1", "字符2", ...}
# 或直接用字符串 "字符1字符2..."
# 新字符串 = '分隔字符串'.join([字符 for 字符 in 原字符串 if 字符 in 保留的字符集合])
#
# # 总结
# join() 核心是「用指定分隔符拼接可迭代对象的字符串元素」，语法为 分隔符.join(可迭代对象)；
# 基础用法：空字符串拼接（无缝合并）、单 / 多字符拼接（格式化输出）；
# 关键避坑：非字符串元素必须先转字符串（用 str() + 列表推导式）；
#
# # 例子
# s = "abc123!@#456xyz789"
# keep_chars = "0123456789"   //只保留 0-9 的数字字符
# result = ''.join([c for c in s if c in keep_chars])
# print(result)  # 输出：123456789
#
# # 10进制转为16进制——hex(10进制数字)   eg：a = hex(16)  # 0x10
# # 16进制转为10进制——int(16进制数字, base = 16)
# 若16进制数字之前有0x则可以省略base参数
# # int() 是 Python 内置函数，支持将任意进制的字符串 / 数字转为十进制整数，是处理十六进制转十进制的首选。

# %%
# 26
str1 = input()
# 第一次清洁，保留字符串
str_retain1 = '0123456789abcdefABCDEF-' 
str_retain2 = '0123456789abcdefABCDEF'  
# 通过拼接字符串，遍历str1，若遍历的str1元素存在于str——retain1中则存入str1_1
str1_1 = ''.join(str2 for str2 in str1 if str2 in str_retain1)
str1_2 = ''.join(str3 for str3 in str1 if str3 in str_retain2)
# 判断第一次清洁后的字符串str1_1是否为空
if str1_2 == '':
    result = 0
else:
    # 判断在第一个十六进制符前面是否含有-号
    if str1_1[0] == '-':
        result = '-'
    else:
        result = ''
    # 去除所有‘-’号
    result_str = str1_1.replace('-', '')
    result += str(int(result_str, 16))
print(int(result))
# Out:
# 0

# %%
# 27
str1 = input()
# 设计保留字符串
str_retain = 'QWERTYUIOPASDFGHJKLZXCVBNM'  # 26个字母
# str_retain中需要剔除的元素
str_retain_to_remove = ['A', 'E', 'I', 'O', 'U']  
# 通过遍历剔除str_retain中的元素
for char in str_retain_to_remove:
    str_retain = str_retain.replace(char, '')
# 此时str_retain中仅含大写的辅音字母
# 建立新字符串来存入str1中需要保留的字符
str_result = ''
for char1 in str1:
    if char1 in str_retain:
        str_result += char1
# 另一种写法：
# str_result = ''.join(char1 for char1 in str1 if char1 in str_retain)
print(len(str_result))
# Out:
# 4

# %%
# 28
# 接收以空格分隔的字符串，存入列表
str_input_to_list = input().split(' ')
# 列表排序（正序）
str_input_to_list.sort()
print('After sorted:')
for char in str_input_to_list:
    print(char)
# Out:
# After sorted:
# black
# blue
# red
# white
# yellow

# %%
# 29
N = int(input())
# 统计N的位数
N_count = len(str(N))
# 通过N对10取余,从N的个位开始，依次取出位数上的数字
# 通过N对10整除,从N的个位开始，依次删除位数上的数字
sum1 = 0
while N//10 != 0:
    N_single = N%10
    N //= 10
    sum1 += N_single
sum1 += N
print('%d %d' %(N_count, sum1))
# Out:
# 3 6

# %%
# 30
str_input = input()
dict_replace = {
    'A':'Z',
    'B':'Y',
    'C':'X',
    'D':'W',
    'E':'V',
    'F':'U',
    'G':'T',
    'H':'S',
    'I':'R',
    'J':'Q',
    'K':'P',
    'L':'O',
    'M':'N',
    'N':'M',
    'O':'L',
    'P':'K',
    'Q':'J',
    'R':'I',
    'S':'H',
    'T':'G',
    'U':'F',
    'V':'E',
    'W':'D',
    'X':'C',
    'Y':'B',
    'Z':'A'
}
# 创新空字符串，来接收结果
str_result =''
# 遍历’输入字符串‘，将其存入结果字符串
for char in str_input:
    # 若’输入字符串’的元素存在于替换字典中，则将该元素替换
    if char in dict_replace:
        char = dict_replace[char]
    str_result += char
print(str_result)
# Out:
# Lnly the 11 XZKRtaO OeGtVIH are replaced.

# %%
# 31
str_input = input()
str_change1 = 'QWERTYUIOPASDFGHJKLZXCVBNM'
str_change2 = str_change1.lower()
str_result = ''
# 遍历输入的字符串
for char in str_input:
    # 若输入字符串中有元素为大写，则变为小写
    if char in str_change1:
        char = char.lower()
    # 若输入字符串中有元素为小写，则变为大写
    elif char in str_change2:
        char = char.upper()
    str_result += char
# 删除字符串末尾的#号
str_result = str_result[0:len(str_result)-1]
print(str_result)
# Out:
# hELLO wORLD! 123

# %%
# 32
str_input_to_list = input().split(' ')
index0 = 0
str_result = []     # 建立空列表存入答案
# 遍历输入的以空格分割的字符串列表
for char in str_input_to_list:
    # 若当前字符为空，且上一个字符也为空，则该字符舍去，否则添加该字符
    if char == '':
        if str_input_to_list[index0-1] == '':
            str_result
    else:        
        str_result.append(char)
    index0 += 1
# 整理后的结果字符串仅剩下‘单词’，输出其列表长度即可
print(len(str_result))
# Out:
# 3

# %%
# 33
str_input = input()
# 通过集合对输入字符串进行去重
set_input = set(str_input)
# 将去重的结果遍历取出——集合中的元素无法直接转为字符串
str_clean = ''.join(char for char in set_input)
# 对字符串进行排序（正序）——sorted方法——返回列表（字符串元素）
# ['2', '3', 'a', 'd', 'e', 'f', 'i', 'j', 'n', 'v', 'z']
str_clean_sort = sorted(str_clean)
# 将该列表各个元素，依次写入字符串
str_result = ''.join(char for char in str_clean_sort)
print(str_result)
# Out:
# 23adefijnvz

# %%
# 34
str_input = input()
str_to_del = input()
# 清除输入字符串的首尾空格字符
str_to_del = str_to_del.strip(' ')
str_input_delblank = str_input.strip(' ')
# 将输入字符串中的待删除字符替换为‘’
str_result = str_input_delblank.replace(str_to_del.upper(), '')
str_result = str_input_delblank.replace(str_to_del.lower(), '')
print(f'result: {str_result}')
# Out:
# result: B

# %%
# 35
str_input = input()
# 通过遍历，将输入字符串所有的英文字母提取出来
str_input_alpha = ''.join(char for char in str_input if char.isalpha())
# 建立空字符串存入结果
str_result = ''
# 建立空列表存入遍历过的字符
list_save = []
for char1 in str_input_alpha:
    # 若char1不在已经遍历过的字符中，则存入结果字符串
    if char1  not in list_save:
        str_result += char1
    # 遍历一个字符，将其的大小写均存入list_save
    list_save.extend([char1.upper(), char1.lower()])
if len(str_result) < 10:
    print('not found')
else:
    print(str_result[0:10])
# Out:
# not found

# %%
#36
N = int(input())
# 创建空列表来存入输入的字符串
list_str_input = []
# 通过遍历来接收各个输入的字符串
for i in range(N):
    str_input = input()
    list_str_input.append(str_input)
# 将接收输入字符串的列表进行排序（反序，以长度为规则）
list_str_input.sort(key=len, reverse=True)
print(f'The longest is: {list_str_input[0]}')
# Out:
# The longest is: zhang

# %%
# 37
num = int(input())
# 将输入的数字转为字符串
num_to_str = str(num)
# 将字符串进行反转
num_to_str = num_to_str[::-1]
print(int(num_to_str))
# Out:
# 321

# %%
# 38
str_input = input()
str_input_rev = str_input[::-1]
if str_input == str_input_rev:
    print(str_input)
    print('Yes')
else:
    print(str_input)
    print('No')
# Out:
# 1 + 2 = 2 + 1 =
# No

# %%
# 39
str_input = input()
# 提取输入字符串的大写英文字母
str_input_upper = ''.join(char0 for char0 in str_input if char0.isupper())
# 创建空集合，来添加遍历后的字符，以便判定后续遍历字符是否存在重复
set_save = set()
# 创建空字符串，来存入结果
str_result = ''
if str_input_upper == '':
    print('Not Found')
else:
    # 遍历处理后仅含大写字母的字符串
    for char in str_input_upper:
        # 若当前遍历的字符之前没出现过，则将其存入结果字符串
        if char not in set_save:
            str_result += char
        # 每次遍历都将当前字符串存入集合中，以便后续遍历判断字符是否在之前出现过
        set_save.add(char)
    print(str_result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[97], line 11
#       9     print('Not Found')
#      10 else:
# ---> 11     for char in str_input_upper:
#      12         if char not in set_save:
#      13             str_result = ''.join(char)
#
# TypeError: 'bool' object is not iterable

# %%
# 40 
n = int(input())
a = 0
for i in range(n+1):
    print(f'pow(3,{a}) = {pow(3, a)}')
    a += 1
# Out:
# pow(3,0) = 1

# %% [markdown]
# # map()方法的简单介绍
# ——Python 中 map() 方法的用法，首先明确核心：map() 是 Python 内置的高阶函数，用于将一个「函数」应用到一个 / 多个「可迭代对象」（列表、元组等）的每个元素上，返回一个迭代器（map 对象），核心作用是批量处理可迭代对象的元素，替代繁琐的循环。
# ——map(函数, 可迭代对象1[, 可迭代对象2, ...])
# ”“”
# 函数：可以是内置函数、自定义函数、lambda 匿名函数，要求能接收「可迭代对象元素数量」的参数（比如处理 2 个可迭代对象时，函数需接收 2 个参数）；
# 可迭代对象：1 个或多个（列表、元组、字符串等），多个时会按位置一一对应取元素；
# 返回值：map 迭代器（需转为列表 / 元组才能直观看到结果）。
# ”“”
# eg：
# # 需求：将字符串列表转为整数列表
# str_list = ["1", "2", "3", "4"]
# # map将int()应用到每个元素，返回迭代器
# result_iter = map(int, str_list)
# # 转为列表查看结果
# result_list = list(result_iter)
# print(result_list)  # 输出：[1, 2, 3, 4]
#
# ps：
# map()方法，返回值是迭代器：map() 返回的是 map 迭代器，不是列表 / 元组，需用 list()/tuple() 转换才能查看结果；且迭代器只能遍历一次，遍历后会清空：
# iter_obj = map(int, ["1", "2"])
# print(list(iter_obj))  # 输出：[1, 2]
# print(list(iter_obj))  # 输出：[]（迭代器已空）
#
# # 用map()方法接收多个输入值
# ——利用 map() 方法接收多个输入值，核心思路是：先通过 input() 获取一行输入的字符串，用 split() 拆分出多个值，再用 map() 将拆分后的字符串批量转换为目标类型（如 int/float），最后转为列表 / 元组提取具体值。这种方式是 Python 中接收多输入的高效写法，下面分场景详细讲解。
# eg：
# 最常用的场景是用户在一行输入多个数字（如 1 2 3 4），需要将其转为整数 / 浮点数列表。
# # 1. 接收输入并拆分 → 2. map转换类型 → 3. 转为列表/元组
# 输入值列表 = list(map(目标类型, input().split()))
# 1.input().split()：将输入的一行字符串按空格拆分（无论多少个空格都拆分），返回字符串列表；
# 2.map(目标类型, ...)：将拆分后的每个字符串转为目标类型（如 int/float）；
# 3.list(...)：将 map 迭代器转为列表，方便后续取值。
# 空格分隔的多值（通用写法）
# 适用于输入用「任意数量空格」分隔的场景（如 1 2 3、a b c），用 split() 拆分（默认按空格拆分，自动忽略多余空格）。
# 具体代码：
# # 示例1：未知输入数量，用列表接收输入值
# nums = list(map(int, input("请输入多个整数（空格分隔）：").split()))
# print(nums)          # 输出：[10, 20, 30, 40]
# print(type(nums[0])) # 输出：<class 'int'>
# -------------------
# # 示例2：已知输入数量，直接解包（更简洁）
# # 输入：1 2
# a, b = map(int, input("请输入2个整数：").split())
# print(f"a={a}, b={b}")  # 输出：a=1, b=2

# %%
# 41
M, N = map(int, input().split())
# 建立空列表，用于存储结果
list_result = []
# 遍历M到N，找出其中的素数
for num in range(M,N+1):
    isprimes = True
    # 先判定该数字是否为1
    if num == 1:
        isprimes = False
    else:
        for i in range(2,num):
            # 若num能和非1和非自身的整除，则不为素数
            if num%i == 0:
                isprimes = False
                break
        # 若isprimes为真，则说明num为素数，添加list_rersult
        if isprimes:
            list_result.append(num)
sum1 = 0
for i in list_result:
    sum1 += i
print(f'{len(list_result)} {sum1}')
# Out:
# 7 143

# %%
# 42
N = int(input())
x = 1
for i in range(N-1):
    x = (x+1)*2
print(x)

# %%
# 43----------------------------------------------
N = int(input())
# 先遍历2——N-1,并找出所有素数
list_primes = []
for num in range(2,N):
    isprimes = True
    # 先判断端点的特殊情况
    if num == 2:
        isprimes = True
    else:
        for i in range(2,num):
            if num%i == 0:
                isprimes = False
                break
        # 若遍历的num为素数，则进一步判断N-num是否为素数
    if isprimes:
        num2 = N-num
        if num2 == 1:
            isprimes = False
        else:
            if num2 == 2:
                isprimes = True
            else:
                for i in range(2,num2):
                    if num2%i==0:
                        isprimes = False
                        break
                # 若num2也为素数，则即为所求
            if isprimes:
                print(f'{N} = {min(num,num2)} + {max(num,num2)}')
                break

# %%
# 44(法1）--------阶乘+累加的两种写法
n = int(input())
sum1_mutiply = 1
sum1 = 1
# 累乘，i+1，则i就乘1次
for i in range(1,n+1):
    # 分母的阶乘
    sum1_mutiply *= i   # (1)*1 (1*1)*2 (1*1*2)*3
    # 通项公式
    an = 1/sum1_mutiply
    sum1 += an
print('%.8f' %sum1)
# Out:
# 2.71828180

# %%
# 44(法2）
n = int(input())
# 定义分母初始值
denominator = 1
# 定义x，后续每次遍历+1，进行累乘
x = 1
# 定义sum1 用于累加
sum1 = 1
for i in range(n):
    # 分母的通项公式，去掉首尾的1，则第n项数即为n！
    denominator *= x
    # 真正通项
    an = 1/denominator
    # 累加通项
    sum1 += an
    # 每次遍历x+1，用于上述阶乘的累计
    x += 1
print('%.8f' %sum1)
# Out:
# 2.71828180

# %%
# 45
# Out:
#           1          1          1          2          2

# %%
# 46---------------------存在非零返回
N = int(input())
# 另一种接收方式
# grade = input().split(' ')——元素为字符串的列表
list_grade = list(map(int,input().split()))
# 处理平均成绩和判断及格人数
# 特别注意！！！！ 
# 不要忘记处理N==0的情况，要不然grade_avg会出现非0返回
if N ==0:
    grade_avg = 0
    grade_passed =0
else:
    grade_avg = sum(list_grade[0:N])/N
    # 判断及格人数
    grade_passed = 0
    for grade in list_grade[0:N]:
        if grade >= 60:
            grade_passed += 1
print(f'average = {grade_avg:.1f}')
print(f'count = {grade_passed}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 2
#       1 # 46
# ----> 2 N = int(input())
#       3 # 另一种接收方式
#       4 # grade = input().split(' ')——元素为字符串的列表
#       5 list_grade = list(map(int,input().split()))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
# 46
N = int(input())
list_grade = input().split(' ')
if N == 0 or list_grade==[]:
    grade_avg = 0
    count = 0
else:
    list_grade_int = list()
    for grade in list_grade[0:N]:
        list_grade_int.append(int(grade))
    grade_avg = sum(list_grade)/len(list_grade)
    count = 0
    for i in list_grade_int:
        if i >=60:
            count +=1
print(f'average = {grade_avg:.1f}')
print(f'{count}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[102], line 11
#       9 for grade in list_grade[0:N]:
#      10     list_grade_int.append(int(grade))
# ---> 11 grade_ave = sum(list_grade)/len(list_grade)
#      12 count = 0
#      13 for i in list_grade_int:
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# 46（豆包修改后）
N = int(input())

# 初始化变量，默认N=0的情况
grade_avg = 0.0
grade_passed = 0

if N != 0:
    # 仅当N≠0时读取成绩，并只取前N个（兜底输入数量不符）
    grade_str_list = input().split()
    # 转换为整数列表，且只保留前N个成绩
    list_grade = list(map(int, grade_str_list))[:N]
    # 计算平均分（确保用N个成绩计算）
    grade_avg = sum(list_grade) / N
    # 统计及格人数
    grade_passed = 0
    for grade in list_grade:
        if grade >= 60:
            grade_passed += 1

# 按格式输出（N=0时输出0.0，N≠0时输出精确到1位小数）
print(f'average = {grade_avg:.1f}')
print(f'count = {grade_passed}')

# %%
# 47
N = int(input())
# 定义初始分子
element = 2
# 定义初始分母
denominator = 1
# 定义求和变量
sum1 = 0
for i in range(N):
    # 通项公式，当前项
    an = element/denominator
    # 通过临时变量储存当前的分子
    a = element
    # 将当前分子与分母相加，求得后一项的分子
    element += denominator
    # 将临时变量中的当前分子项赋给分母，求得后一项的分母
    denominator = a
    # 累加求和
    sum1 += an
print(f'{sum1:.2f}')
# Out:
# 32.66

# %%
# 48
# 菜单界面
print('[1] apple')
print('[2] pear')
print('[3] orange')
print('[4] grape')
print('[0] exit')

# 定义字典，创建水果（数字）与价格的对应关系
dict_price = {
    1:3,
    2:2.5,
    3:4.1,
    4:10.2
}
# 接收输入值
list_a = list(map(int, input().split()))
count = 0
# 遍历输入的查询值
for i in list_a:
    # 查询次数为5时，或输入0则退出查询
    if count == 5 or i == 0:
        break
    # 查询1-4
    elif 0<i<5:
        print(f'price = {dict_price[i]:.2f}')
    # 输入其他值时，查询价格为0.00
    else:
        print(f'price = {0.00:.2f}')
    count += 1
# Out:
# [1] apple
# [2] pear
# [3] orange
# [4] grape
# [0] exit
# price = 3.00
# price = 2.50
# price = 4.10
# price = 4.10
# price = 10.20

# %%
# 49
M, N = map(int,input().split())
# 从M，N中较小的数字开始遍历到1
for i in range(min(M,N),0,-1):
    # 若i能与N和M同时整除，则其为最大公约数
    if N%i==0 and M%i ==0:
        result1_GCD = i # 最大公约数GCD
        break
# 最小公倍数（LCM) = (两数乘积)/最大公约数
result2_LCM = (M*N)/result1_GCD
print('%d %d' %(result1_GCD, result2_LCM))
# Out:
# 73 2044

# %%
# 50
# 接收输入次数
N = int(input())
# 遍历N次，进行N次输入，并把输入值存入列表
list_input = []
for i in range(N):
    num = int(input())
    list_input.append(num)
# 逐一判定列表中的数，是否为素数
for num in list_input:
    # 先判定1和2的特殊情况
    if num == 1:
        print('No')
    elif num == 2:
        print('Yes')
    else:
        isprimes = True
        # 遍历2——num-1
        for i in range(2,num):
            # 若num能与某数整除，则其不为素数，跳出判定循环
            if num%i == 0:
                isprimes = False
                break
        # 若为素数（True），则输出Yes，否则，输出No
        if isprimes:
            print('Yes')
        else:
            print('No')

# %%
# 51--------------------斐波那契数列的写法
n = int(input())
a = 1
b = 1
while a<n:
    a += b
    a, b = b, a
print(a)
# Out:
# 13

# %%
# 52
error = float(input())
sum1 = 1
sum2 = 1
denominator = 1
a = 1
while True:
    # 循环依次denominator*上次的denominator一次
    # 循环n次，得到denominator的n阶乘
    denominator *= a
    an = 1/denominator
    # 前i项和
    sum1 += an
    # 当前的前i项和-上次的前i项目和
    if sum1 - sum2 <error:
        print('%.6f'%sum1)
        break
    # 把当前的前i项和赋值给sum2
    sum2 = sum1
    # 循环一次，denominator+1
    a += 1
# Out:
# 2.718282

# %%
# 53---------------------------------------------
# 定义空字符串，分行存贮输入的字符串
# 定义enter，遍历一次+1，记录换行字符的数目
str1 = ''
enter = 0
# 分行接收输入的字符串
while len(str1) < 10:
    # 分行接收输入，并将输入的字符串拼接到str1上
    str_input = input()
    str1 += str_input
    # 记录换行个数
    enter += 1
# 用列表表达式，遍历str1，统计其中的字母字符
letter = len([char for char in str1 if char.isalpha()])
# str1中的空格字符+换行字符
blank = str1.count(' ') + enter
digit = len([char for char in str1 if char.isdigit()])
# 其他字符个数= len(str1)-字母字符-空白字符-数字字符
other = len(str1)-letter-str1.count(' ')-digit
print(f'letter = {letter}, blank = {blank}, digit = {digit}, other = {other}')
print(enter)
print(str1.count(' '))

# %%
# 54--------------------------------------------------------------------------------
"""
1. 约束条件
设拆分后 5 的个数为 x，2 的个数为 y，1 的个数为 z，需满足：
核心等式：5x + 2y + z = 目标数字n
约束条件：x ≥ 1、y ≥ 1、z ≥ 1（三个数字至少各一个）
取值范围：x 最大为 (n - 2 - 1) // 5（因为要预留 21 + 11 = 3 给 y 和 z）；y 最大为 (n - 5 - 1) // 2；z 由等式推导 z = n -5x -2y。
2. 实现步骤
① 确定 x（5 的个数）的枚举范围：1 ≤ x ≤ (n-3)//5（n-3 是预留 2+1 给 y、z）；② 对每个 x，确定 y（2 的个数）的枚举范围：1 ≤ y ≤ (n-5x-1)//2（预留 1 给 z）；③ 计算 z = n -5x -2y，若 z ≥ 1，则 (x,y,z) 是合法拆分；④ 收集所有合法拆分组合，或判断是否存在拆分。

若先确定z，在确定y，从而确定x，则思路如下：
1. 变量关系重新梳理
设目标数字为 n，拆分后：
核心等式：5x = n - 2y - z → x = (n - 2y - z) / 5
约束条件：
x ≥ 1、y ≥ 1、z ≥ 1（三个数字至少各一个）
x 必须是正整数（因为 5 的个数只能是整数）
取值范围：
z（1 的个数）：最小 1，最大 n - 5 - 2 = n-7（预留 51 + 21 给 x、y）；
对每个 z，y（2 的个数）：最小 1，最大 (n - z - 5) // 2（预留 5*1 给 x）；
最后验证 (n - 2y - z) 是否能被 5 整除，且结果 ≥1（即 x ≥1）。
2. 实现步骤
① 枚举 z（1 的个数）：1 ≤ z ≤ n-7（n-7 是预留 5+2 给 x、y）；② 对每个 z，枚举 y（3 的个数）：1 ≤ y ≤ (n - z -5) // 2；③ 计算剩余值 remain = n - 2y - z，若 remain ≥5 且 remain %5 ==0（即 x 是正整数），则 x = remain //5 是合法值；④ 收集所有满足条件的 (x,y,z) 组合。
"""

n = int(input())
count = 0
for z in range(1, (n-7)+1):
    for y in range(1, ((n-z-5)//2)+1):
        remain = n - z - 2*y
        if remain >= 5 and remain%5 == 0:
            x = remain//5
            print(f'fen5:{x}, fen2:{y}, fen1:{z}, total:{x+y+z}')
            count += 1
print(f'count = {count}')
# Out:
# fen5:2, fen2:1, fen1:1, total:4
# fen5:1, fen2:3, fen1:2, total:6
# fen5:1, fen2:2, fen1:4, total:7
# fen5:1, fen2:1, fen1:6, total:8
# count = 4

# %%
# 54----------------------------------------------------
n = int(input())
count = 0
list1 = []
for x in range(1, ((n-3)//5)+1):
    for y in range(1,((n-5*x-1)//2)+1):
        z = n - 5*x - 2*y 
        if z >= 1:
            list1.append([x, y, z])
            count += 1
list1.reverse()
for i in range(count):
    print(f'fen5:{list1[i][0]}, fen2:{list1[i][1]}, fen1:{list1[i][2]}, total:{sum(list1[i])}')
print(f'count = {count}')
# Out:
# fen5:2, fen2:1, fen1:1, total:4
# fen5:1, fen2:3, fen1:2, total:6
# fen5:1, fen2:2, fen1:4, total:7
# fen5:1, fen2:1, fen1:6, total:8
# count = 4

# %%
# 55
a,b,c = map(int,input().split())
list1 = [a,b,c]
min1 = min(a,b,c)
max1 = max(a,b,c)
list1.remove(min1)
list1.remove(max1)
if min1 + list1[0] > max1:
    print('yes')
else:
    print('no')
# Out:
# 1
# 1

# %%
# 56
N = int(input())
for i in range(10**(N-1), 10**N):
    sum1 = 0
    i_save = i
    for num in range(N):
        # 取个位
        a = i%10
        # 除掉个位
        i = i//10
        # 每位进行求自幂数，在累加
        sum1 += a**N
    if sum1 == i_save:
        print(i_save)
# Out:
# 54748
# 92727
# 93084

# %%
# 57
N = int(input())
list1 = []
for i in range(N):
    list1.append(i+1)
while len(list1)>1:
    a = N//3
    if a>0:
# Out:
# [1, 2]

# %%
# 58
N = int(input())
sum1 = 0
sum2 = 0
n = N
a=-3
for i in range(N):
    num_input = list(map(int, input().split()))
    if n != 0:
        sum1 += sum(num_input[0:n-1])
        if a<
        sum2 += sum(num_input[-2:a])
    n -= 1

# %%
N = int(input())
list1 = []
for i in range(N):
    num_input = list(map(int,input().split()))
    list1.extend(num_input)
for row in list1:
# Out:
# 1
# 2

# %%
# 70
dict1 = {
    1:'Mon',
    2:'Tue',
    3:'Wed',
    4:'Thu',
    5:'Fri',
    6:'Sat',
    7:'Sun'
}
a = int(input())
print(dict1[a])
# Out:
# Mon

# %%
# 71
# 接收输入
N = int(input())
# 定义空列表，用于后续存储输入的字符串形式字典
list1 = []
# 用于统计最终边数
count_edge = 0
# 用于统计边长总和
sum1 = 0
# N次输入，遍历N次
for i in range(N):
    # 用eval解析字符串形式的字典容器
    dict_input = eval(input())
    # 将字典添加入list1
    # eg:
    """
    {'a':{'b':10,'c':6}}
    {'b':{'c':2,'d':7}}
    {'c':{'d':10}}
    {'d':{}} 
    """
    list1.append(dict_input)
# 遍历列表，将每个顶点对应的字典取出
for dict1 in list1:
    # 遍历当前取出的顶点字典
    # 获取顶点字典的key，并获取该顶点对应的内部字典
    # dict1[key]——该顶点与哪些顶点连接
    for key in dict1:
        # 统计当前顶点字典对应的内部字典长度——统计该顶点连接的边的个数，并进行累加
        count_edge_onedot = len(dict1[key])
        count_edge += count_edge_onedot
        # 每遍历一次顶点字典，进入该顶点字典的value
        # 并且遍历内部字典，获取其key，统计内部连接边的长度，并且进行累加。
        for key_dot in dict1[key]:
            len_edge = dict1[key][key_dot]
            sum1 += len_edge
            
print('%d %d %d' %(N, count_edge, sum1))
# Out:
# 4 5 35

# %%
# 72
# 用num（集合形式）记录输入的数据
num = set(map(int,input().split(',')))
set2 = {6,7,8,9,10}
# 取set2中有，但num中没有的元素——取差集
# 即第二小队中没有的票的队员
# 另一种写法 set2_no_vote = set2-num
set2_no_vote = set2.difference(num)
result = ' '.join(map(str, sorted(set2_no_vote)))
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[236], line 9
#       5 # 取set2中有，但num中没有的元素——取差集
#       6 # 即第二小队中没有的票的队员
#       7 # 另一种写法 set2_no_vote = set2-num
#       8 set2_no_vote = set2.difference(num)
# ----> 9 result = ' '.join(sorted(set2_no_vote))
#      10 print(result)
#
# TypeError: sequence item 0: expected str instance, int found

# %%
# 73
str_input = input()
str1 = input()
print(str_input.count(str1))
# Out:
# 2
